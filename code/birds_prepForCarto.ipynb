# %%
import pandas as pd

# %%
cd ..
# Out:
# /Users/mgcrp/Documents/GitHub/hse_graphvis_2021

# %%
cd data/
# Out:
# /Users/mgcrp/Documents/GitHub/hse_graphvis_2021/data

# %%
files = [
    '0228685-200613084148143.csv',
    '0228687-200613084148143.csv',
    '0228689-200613084148143.csv',
    '0228693-200613084148143.csv',
    '0228696-200613084148143.csv',
    '0228699-200613084148143.csv'
]

df = pd.read_csv(files[0], sep='\t')

for file in files[1:]:
    df = df.append( pd.read_csv(file, sep='\t') )
# Out:
# /Users/mgcrp/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (14,17,36,38,39,40,41,44,46,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/mgcrp/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (17,38,39,40,41,46,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/mgcrp/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10,38,39,40,41,46,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(10)
# Out:
#        gbifID                            datasetKey  \
# 0  1615092473  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 1  1615092515  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 2  1620594793  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 3  1615097451  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 4  1620634274  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 5  1620651512  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 6  1615101713  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 7  1615101724  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 8  1620594782  f06fef3c-6ea6-4345-b724-a1b8e490dc55
# 9  1615092547  f06fef3c-6ea6-4345-b724-a1b8e490dc55
#
#                            occurrenceID   kingdom    phylum class  \
# 0  SEO-BirdLife:anillamientoseo:3695428  Animalia  Chordata  Aves
# 1  SEO-BirdLife:anillamientoseo:3695420  Animalia  Chordata  Aves
# 2  SEO-BirdLife:anillamientoseo:8707595  Animalia  Chordata  Aves
# 3  SEO-BirdLife:anillamientoseo:3699894  Animalia  Chordata  Aves
# 4  SEO-BirdLife:anillamientoseo:8743142  Animalia  Chordata  Aves
# 5  SEO-BirdLife:anillamientoseo:8758670  Animalia  Chordata  Aves
# 6  SEO-BirdLife:anillamientoseo:3703753  Animalia  Chordata  Aves
# 7  SEO-BirdLife:anillamientoseo:3703747  Animalia  Chordata  Aves
# 8  SEO-BirdLife:anillamientoseo:8707598  Animalia  Chordata  Aves
# 9  SEO-BirdLife:anillamientoseo:3695475  Animalia  Chordata  Aves
#
#              order        family     genus            species  ...  \
# 0    Passeriformes     Alaudidae    Alauda    Alauda arvensis  ...
# 1    Passeriformes     Alaudidae    Alauda    Alauda arvensis  ...
# 2  Charadriiformes  Scolopacidae  Calidris    Calidris alpina  ...
# 3    Passeriformes  Muscicapidae  Oenanthe  Oenanthe oenanthe  ...
# 4  Charadriiformes  Scolopacidae  Calidris    Calidris alpina  ...
# 5  Charadriiformes  Scolopacidae  Calidris    Calidris alpina  ...
# 6    Passeriformes  Muscicapidae  Oenanthe  Oenanthe oenanthe  ...
# 7    Passeriformes  Muscicapidae  Oenanthe  Oenanthe oenanthe  ...
# 8  Charadriiformes  Scolopacidae  Calidris    Calidris alpina  ...
# 9    Passeriformes     Alaudidae    Alauda    Alauda arvensis  ...
#
#   identifiedBy dateIdentified       license  rightsHolder recordedBy  \
# 0          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 1          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 2          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 3          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 4          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 5          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 6          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 7          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 8          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
# 9          NaN            NaN  CC_BY_NC_4_0  SEO-BirdLife        NaN
#
#   typeStatus establishmentMeans           lastInterpreted mediaType  issue
# 0        NaN             NATIVE  2021-03-09T20:47:25.985Z       NaN    NaN
# 1        NaN             NATIVE  2021-03-09T20:46:38.909Z       NaN    NaN
# 2        NaN             NATIVE  2021-03-09T20:46:58.292Z       NaN    NaN
# 3        NaN             NATIVE  2021-03-09T20:47:24.254Z       NaN    NaN
# 4        NaN             NATIVE  2021-03-09T20:47:17.765Z       NaN    NaN
# 5        NaN             NATIVE  2021-03-09T20:46:43.663Z       NaN    NaN
# 6        NaN             NATIVE  2021-03-09T20:46:42.306Z       NaN    NaN
# 7        NaN             NATIVE  2021-03-09T20:47:24.393Z       NaN    NaN
# 8        NaN             NATIVE  2021-03-09T20:47:02.284Z       NaN    NaN
# 9        NaN             NATIVE  2021-03-09T20:46:38.909Z       NaN    NaN
#
# [10 rows x 50 columns]
